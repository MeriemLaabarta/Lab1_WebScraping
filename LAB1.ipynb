# %%
import requests

# %%
url = "https://github.com/search?q=mental+health+ai&type=repositories"
reponse = requests.get(url)

# %%
print(reponse.status_code)
# Out:
# 200

# %%
with open("github_results.txt", "w", encoding="utf-8") as f:
    f.write(reponse.text)

print("Le contenu HTML a été sauvegardé dans github_results.txt")
# Out:
# Le contenu HTML a été sauvegardé dans github_results.txt

# %%
entetes = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
,
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8",
    "Accept-Language": "fr,fr-FR;q=0.8,en-US;q=0.5,en;q=0.3",
    "Referer": "https://github.com/"
}
